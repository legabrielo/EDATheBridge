# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
appearances = pd.read_csv("C:\\Users\\Gabriel Castillo\\Desktop\\GITHUB GABRIEL\\EDA\\Futbol\\appearances.csv")
games = pd.read_csv("C:\\Users\\Gabriel Castillo\\Desktop\\GITHUB GABRIEL\\EDA\\Futbol\\games.csv")
players = pd.read_csv("C:\\Users\\Gabriel Castillo\\Desktop\\GITHUB GABRIEL\\EDA\\Futbol\\players.csv")
player_valuations = pd.read_csv("C:\\Users\\Gabriel Castillo\\Desktop\\GITHUB GABRIEL\\EDA\\Futbol\\player_valuations.csv")
competitions = pd.read_csv("C:\\Users\\Gabriel Castillo\\Desktop\\GITHUB GABRIEL\\EDA\\Futbol\\competitions.csv")
clubs = pd.read_csv("C:\\Users\\Gabriel Castillo\\Desktop\\GITHUB GABRIEL\\EDA\\Futbol\\clubs.csv")

# %%
appearances
# Out:
#          player_id  game_id   appearance_id competition_id  player_club_id  \
# 0            52453  2483937   2483937_52453            RU1           28095
# 1            67064  2479929   2479929_67064            RU1           28095
# 2            67064  2483937   2483937_67064            RU1           28095
# 3            67064  2484582   2484582_67064            RU1           28095
# 4            67064  2485965   2485965_67064            RU1           28095
# ...            ...      ...             ...            ...             ...
# 1072827     369552  3837232  3837232_369552            NL1             200
# 1072828     369552  3837391  3837391_369552            NL1             200
# 1072829     369552  3837395  3837395_369552            NL1             200
# 1072830     369552  3839703  3839703_369552            NL1             200
# 1072831     369552  3839707  3839707_369552            NL1             200
#
# ...

# %%
appearances.shape
# Out:
# (1072832, 12)

# %%
games
# Out:
#        game_id competition_code  season                     round        date  \
# 0      2244388              SUC    2012             final 1st leg  2012-08-22
# 1      2219794             BESC    2011                     Final  2012-07-22
# 2      2244389              SUC    2012             final 2nd leg  2012-08-29
# 3      2271112              DFB    2012               Round of 16  2012-12-18
# 4      2229332              DFL    2012                     Final  2012-08-12
# ...        ...              ...     ...                       ...         ...
# 57765  3911792               CL    2022                   Group C  2022-09-13
# 57766  3901635             ECLQ    2022  Qualifying Round 2nd leg  2022-08-25
# 57767  3911795               CL    2022                   Group D  2022-09-07
# 57768  3911799               CL    2022                   Group D  2022-09-07
# 57769  3911739               CL    2022                   Group B  2022-09-13
#
# ...

# %%
games.shape
# Out:
# (57770, 18)

# %%
players
# Out:
#        player_id  last_season  current_club_id                name  \
# 0         254016         2013              855    arthur-delalande
# 1          51053         2013               23       daniel-davari
# 2          31451         2013               23       torsten-oehrl
# 3          44622         2013             3691   vladimir-kisenkov
# 4          30802         2013             3302          oscar-diaz
# ...          ...          ...              ...                 ...
# 25603     257448         2022              162      gelson-martins
# 25604     810092         2022              583  warren-zaire-emery
# 25605     182891         2022              162     thomas-didillon
# 25606     369552         2022              200       luuk-brouwers
# 25607      68290         2022              583              neymar
#
#               pretty_name country_of_birth country_of_citizenship  \
# 0        Arthur Delalande           France                 France
# ...

# %%
players.shape
# Out:
# (25608, 21)

# %%
player_valuations
# Out:
#         player_id        date  market_value    datetime    dateweek  \
# 0          254016  2013-07-22         90000  2013-07-22  2013-07-22
# 1          254016  2014-01-14         90000  2014-01-14  2014-01-13
# 2           51053  2008-08-25         90000  2008-08-25  2008-08-25
# 3           51053  2011-05-30         90000  2011-05-30  2011-05-30
# 4           51053  2011-08-26        225000  2011-08-26  2011-08-22
# ...           ...         ...           ...         ...         ...
# 368805      68290  2020-10-15     115200000  2020-10-15  2020-10-12
# 368806      68290  2021-04-09      99000000  2021-04-09  2021-04-05
# 368807      68290  2021-06-04      90000000  2021-06-04  2021-05-31
# 368808      68290  2021-12-16      81000000  2021-12-16  2021-12-13
# 368809      68290  2022-05-30      67500000  2022-05-30  2022-05-30
#
#         current_club_id player_club_domestic_competition_id
# 0                   855                                 FR1
# ...

# %%
player_valuations.shape
# Out:
# (368810, 7)

# %%
competitions
# Out:
#    competition_id                                         name  \
# 0              L1                                   bundesliga
# 1             DFB                                    dfb-pokal
# 2             DFL                                 dfl-supercup
# 3             NL1                                   eredivisie
# 4             NLP                              toto-knvb-beker
# 5            NLSC                         johan-cruijff-schaal
# 6             BE1                           jupiler-pro-league
# 7            BESC                             belgian-supercup
# 8             ES1                                       laliga
# 9             CDR                                 copa-del-rey
# 10            SUC                                    supercopa
# 11            PO1                           liga-portugal-bwin
# 12           POCP                                  allianz-cup
# 13           POSU                supertaca-candido-de-oliveira
# ...

# %%
competitions.shape
# Out:
# (42, 10)

# %%
competitions.loc[8]
# Out:
# competition_id                                                        ES1
# name                                                               laliga
# type                                                           first_tier
# country_id                                                            157
# country_name                                                        Spain
# domestic_league_code                                                  ES1
# confederation                                                      europa
# url                     https://www.transfermarkt.co.uk/laliga/startse...
# country_latitude                                                39.326068
# country_longitude                                               -4.837979
# Name: 8, dtype: object

# %%
clubs
# Out:
#      club_id                 name          pretty_name  \
# 0       1032           fc-reading           Fc Reading
# 1       2323             orduspor             Orduspor
# 2       1387       acn-siena-1904       Acn Siena 1904
# 3       1071       wigan-athletic       Wigan Athletic
# 4       2703  spartak-vladikavkaz  Spartak Vladikavkaz
# ..       ...                  ...                  ...
# 405      162            as-monaco            As Monaco
# 406      826              rc-lens              Rc Lens
# 407      467         nec-nijmegen         Nec Nijmegen
# 408     1421          stade-reims          Stade Reims
# 409     1095         es-troyes-ac         Es Troyes Ac
#
#     domestic_competition_id  total_market_value  squad_size  average_age  \
# 0                       GB1               33.66          26         25.9
# 1                       TR1                 NaN           0          NaN
# 2                       IT1                4.32          30         26.2
# ...

# %%
clubs.shape
# Out:
# (410, 15)

# %%
# players.groupby("player_pretty_name").sum()
# Out:
#                        player_id    game_id  player_club_id  goals  assists  \
# player_pretty_name
#  Alpha Bdul Razak         339560    2494440           28956      0        0
# A J Soares               1061100   16185193            4068      1        0
# Aaron Appindangoye      17543181  224896380          165387      0        1
# Aaron Bastiaans           578459    3216176            1426      1        0
# Aaron Boupendza         15821385  126600984          283249     22        1
# ...                          ...        ...             ...    ...      ...
# Zuriko Davitashvili     20523456  161638028          147724      2        0
# Zvonimir Sarlija        16913520  158275815          103269      1        1
# Zvonimir Vukic             43626    7483214            6237      0        0
# Zydrunas Karcemarskas    1912472  326045333          218808      0        0
# Zymer Bytyqi            14308185  240813212          151577     11       13
#
# ...

# %%
# players.shape
# Out:
# (1072832, 12)

# %%
# players.sort_values(by = ["player_pretty_name"], ascending=[True]).sum()

# %%
# players_goals = players.groupby(by=["competition_id", "player_club_id"]).count()["player_id"]
# players_goals
# Out:
# competition_id  player_club_id
# BE1             58                3548
#                 157               3573
#                 172               3562
#                 204                412
#                 354               3108
#                                   ...
# USC             368                 57
#                 418                 73
#                 631                 32
#                 985                 13
#                 1050                17
# Name: player_id, Length: 1869, dtype: int64

# %%
# games = pd.read_csv()
