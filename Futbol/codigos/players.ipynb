# %% [markdown]
# ESTE DATASET YA ESTA TERMINADO

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
players =  pd.read_csv("C:\\Users\\Gabriel Castillo\\Desktop\\GITHUB GABRIEL\\EDA\\EDATheBridge\\Futbol\\data\\vieja\\players.csv")
players.head(3)
# Out:
#    player_id  last_season  current_club_id              name  \
# 0     254016         2013              855  arthur-delalande
# 1      51053         2013               23     daniel-davari
# 2      31451         2013               23     torsten-oehrl
#
#         pretty_name country_of_birth country_of_citizenship date_of_birth  \
# 0  Arthur Delalande           France                 France    1992-05-18
# 1     Daniel Davari          Germany                   Iran    1988-01-06
# 2     Torsten Oehrl          Germany                Germany    1986-01-07
#
#      position      sub_position  ... height_in_cm  market_value_in_gbp  \
# 0    Midfield  Central Midfield  ...          186                  NaN
# 1  Goalkeeper               NaN  ...          192             135000.0
# 2      Attack    Centre-Forward  ...          192                  NaN
#
#    highest_market_value_in_gbp  agent_name image_url  \
# 0                      90000.0         NaN       NaN
# ...

# %%
players.columns
# Out:
# Index(['player_id', 'last_season', 'current_club_id', 'name', 'pretty_name',
#        'country_of_birth', 'country_of_citizenship', 'date_of_birth',
#        'position', 'sub_position', 'foot', 'height_in_cm',
#        'market_value_in_gbp', 'highest_market_value_in_gbp', 'agent_name',
#        'image_url', 'url', 'club_id', 'domestic_competition_id', 'club_name',
#        'club_pretty_name'],
#       dtype='object')

# %%
play = players.groupby(["domestic_competition_id", "player_id","pretty_name", "last_season"])[["current_club_id", "domestic_competition_id"]].sum().reset_index()
play
# Out:
#       domestic_competition_id  player_id       pretty_name  last_season  \
# 0                         BE1       3176  Eidur Gudjohnsen         2013
# 1                         BE1       3354  Jonathan Blondel         2014
# 2                         BE1       3441      Timmy Simons         2017
# 3                         BE1       4323   Jelle Van Damme         2018
# 4                         BE1       4377     Thomas Buffel         2018
# ...                       ...        ...               ...          ...
# 25603                    UKR1    1045568      Danylo Golub         2022
# 25604                    UKR1    1048954     Igor Potimkov         2022
# 25605                    UKR1    1050249  Denys Shevchenko         2022
# 25606                    UKR1    1050852    Vitaliy Kholod         2022
# 25607                    UKR1    1064515  Leonardo Almeida         2022
#
#        current_club_id
# 0                 2282
# 1                 2282
# 2                 2282
# ...

# %%
play[play["pretty_name"] == "Lionel Messi"]
# Out:
#      domestic_competition_id  player_id   pretty_name  last_season  \
# 5069                     FR1      28003  Lionel Messi         2022
#
#       current_club_id
# 5069              583

# %%
# play1 =play[(play["domestic_competition_id"] == "ES1")].sort_values(by="last_season").reset_index(0).drop(["index"], axis=1)
# play1

# %%
# play.dtypes

# %%
# play1[play1["pretty_name"] == "Lionel Messi"]
# Out:
# Empty DataFrame
# Columns: [domestic_competition_id, player_id, pretty_name, last_season, current_club_id]
# Index: []

# %%
play.to_csv("C:\\Users\\Gabriel Castillo\\Desktop\\GITHUB GABRIEL\\EDA\\EDATheBridge\\Futbol\\data\\filtrada\\play.csv")
# SE CREA EL NUEVO CSV Y SE GUARDA
