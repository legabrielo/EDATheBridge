# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
clubs = pd.read_csv("C:\\Users\\Gabriel Castillo\\Desktop\\GITHUB GABRIEL\\EDA\\EDATheBridge\\Futbol\\data\\clubs.csv")
clubs.head()
# Out:
#    club_id                 name          pretty_name domestic_competition_id  \
# 0     1032           fc-reading           Fc Reading                     GB1
# 1     2323             orduspor             Orduspor                     TR1
# 2     1387       acn-siena-1904       Acn Siena 1904                     IT1
# 3     1071       wigan-athletic       Wigan Athletic                     GB1
# 4     2703  spartak-vladikavkaz  Spartak Vladikavkaz                     RU1
#
#    total_market_value  squad_size  average_age  foreigners_number  \
# 0               33.66          26         25.9                 12
# 1                 NaN           0          NaN                  0
# 2                4.32          30         26.2                  6
# 3               12.38          29         26.5                 14
# 4                 NaN           1         20.0                  0
#
#    foreigners_percentage  national_team_players                stadium_name  \
# ...

# %%
clubs.columns
# SE MIRAN LAS COLUMNAS PARA SABER CUALES SON LOS DATOS QUE NOS INTERESAN
# Out:
# Index(['club_id', 'name', 'pretty_name', 'domestic_competition_id',
#        'total_market_value', 'squad_size', 'average_age', 'foreigners_number',
#        'foreigners_percentage', 'national_team_players', 'stadium_name',
#        'stadium_seats', 'net_transfer_record', 'coach_name', 'url'],
#       dtype='object')

# %%
club1 = clubs.groupby(["pretty_name", "domestic_competition_id"])[["squad_size", "national_team_players","club_id"]].sum().reset_index()
club1.head(25)
#  SE CREA EL NUEVO CSV PARA VER LOS JUGADORES, LA COMPETICION, CUANTOS JUGADORES Y LOS JUGADORES DEL PAIS
# Out:
#           pretty_name domestic_competition_id  squad_size  \
# 0           1 Fc Koln                      L1          28
# 1       1 Fc Nurnberg                      L1          28
# 2   1 Fc Union Berlin                      L1          29
# 3      1 Fsv Mainz 05                      L1          27
# 4          Aalborg Bk                     DK1          22
# 5           Aarhus Gf                     DK1          23
# 6         Aberdeen Fc                     SC1          24
# 7          Ac Ajaccio                     FR1          31
# 8          Ac Florenz                     IT1          28
# 9          Ac Horsens                     DK1          20
# 10         Ac Mailand                     IT1          31
# 11           Ac Monza                     IT1          37
# 12  Academica Coimbra                     PO1          30
# 13     Acn Siena 1904                     IT1          30
# 14    Adana Demirspor                     TR1          32
# ...

# %%
espana = club1[club1["domestic_competition_id"]== "ES1"].reset_index(0).drop(["index"], axis=1)
espana
# USAMOS SOLO LOS CLUBES DE ESPAÑA PARA SABER LOS EQUIPOS Y SU CLUB_ID. ESTE CLUB_ID SE VA A USAR PARA HACER EL MERGE
# Out:
#                     pretty_name domestic_competition_id  squad_size  \
# 0               Athletic Bilbao                     ES1          26
# 1               Atletico Madrid                     ES1          22
# 2                    Ca Osasuna                     ES1          24
# 3                    Cd Leganes                     ES1          28
# 4                    Celta Vigo                     ES1          22
# 5              Deportivo Alaves                     ES1          26
# 6           Deportivo La Coruna                     ES1          24
# 7            Espanyol Barcelona                     ES1          21
# 8                  Fc Barcelona                     ES1          25
# 9                      Fc Cadiz                     ES1          27
# 10                   Fc Cordoba                     ES1          24
# 11                     Fc Elche                     ES1          25
# 12                    Fc Getafe                     ES1          24
# ...

# %%
espana.count(axis=0)
# Out:
# pretty_name                32
# domestic_competition_id    32
# squad_size                 32
# national_team_players      32
# club_id                    32
# dtype: int64

# %%
espana
# Out:
#                      pretty_name domestic_competition_id  squad_size  \
# 50               Athletic Bilbao                     ES1          26
# 51               Atletico Madrid                     ES1          22
# 70                    Ca Osasuna                     ES1          24
# 78                    Cd Leganes                     ES1          28
# 82                    Celta Vigo                     ES1          22
# 95              Deportivo Alaves                     ES1          26
# 96           Deportivo La Coruna                     ES1          24
# 113           Espanyol Barcelona                     ES1          21
# 119                 Fc Barcelona                     ES1          25
# 125                     Fc Cadiz                     ES1          27
# 127                   Fc Cordoba                     ES1          24
# 130                     Fc Elche                     ES1          25
# 136                    Fc Getafe                     ES1          24
# ...
