# %% [markdown]
# ESTE DATASET YA ESTA TERMINADO

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
clubs = pd.read_csv("C:\\Users\\Gabriel Castillo\\Desktop\\GITHUB GABRIEL\\EDA\\EDATheBridge\\Futbol\\data\\vieja\\clubs.csv")
clubs.head()
# Out:
#    club_id                 name          pretty_name domestic_competition_id  \
# 0     1032           fc-reading           Fc Reading                     GB1
# 1     2323             orduspor             Orduspor                     TR1
# 2     1387       acn-siena-1904       Acn Siena 1904                     IT1
# 3     1071       wigan-athletic       Wigan Athletic                     GB1
# 4     2703  spartak-vladikavkaz  Spartak Vladikavkaz                     RU1
#
#    total_market_value  squad_size  average_age  foreigners_number  \
# 0               33.66          26         25.9                 12
# 1                 NaN           0          NaN                  0
# 2                4.32          30         26.2                  6
# 3               12.38          29         26.5                 14
# 4                 NaN           1         20.0                  0
#
#    foreigners_percentage  national_team_players                stadium_name  \
# ...

# %%
clubs.columns
# SE MIRAN LAS COLUMNAS PARA SABER CUALES SON LOS DATOS QUE NOS INTERESAN
# Out:
# Index(['club_id', 'name', 'pretty_name', 'domestic_competition_id',
#        'total_market_value', 'squad_size', 'average_age', 'foreigners_number',
#        'foreigners_percentage', 'national_team_players', 'stadium_name',
#        'stadium_seats', 'net_transfer_record', 'coach_name', 'url'],
#       dtype='object')

# %%
clubs.groupby(["pretty_name", "domestic_competition_id"])[["squad_size", "national_team_players","club_id"]].sum().reset_index()
clubs
#  SE FILTRA EL CSV PARA VER LOS JUGADORES, LA COMPETICION, CUANTOS JUGADORES Y LOS JUGADORES DEL PAIS
# Out:
#      club_id                 name          pretty_name  \
# 0       1032           fc-reading           Fc Reading
# 1       2323             orduspor             Orduspor
# 2       1387       acn-siena-1904       Acn Siena 1904
# 3       1071       wigan-athletic       Wigan Athletic
# 4       2703  spartak-vladikavkaz  Spartak Vladikavkaz
# ..       ...                  ...                  ...
# 405      162            as-monaco            As Monaco
# 406      826              rc-lens              Rc Lens
# 407      467         nec-nijmegen         Nec Nijmegen
# 408     1421          stade-reims          Stade Reims
# 409     1095         es-troyes-ac         Es Troyes Ac
#
#     domestic_competition_id  total_market_value  squad_size  average_age  \
# 0                       GB1               33.66          26         25.9
# 1                       TR1                 NaN           0          NaN
# 2                       IT1                4.32          30         26.2
# ...

# %%
espana = clubs[clubs["domestic_competition_id"]== "ES1"].reset_index(0).drop(["index"], axis=1)
espana
# USAMOS SOLO LOS CLUBES DE ESPAÑA PARA SABER LOS EQUIPOS Y SU CLUB_ID. ESTE CLUB_ID SE VA A USAR PARA HACER EL MERGE
# Out:
#     club_id                         name                  pretty_name  \
# 0       142               real-saragossa               Real Saragossa
# 1       993                   fc-cordoba                   Fc Cordoba
# 2      2448               sporting-gijon               Sporting Gijon
# 3      1084                    fc-malaga                    Fc Malaga
# 4       897          deportivo-la-coruna          Deportivo La Coruna
# 5       472                ud-las-palmas                Ud Las Palmas
# 6      1244                   cd-leganes                   Cd Leganes
# 7      1533                     sd-eibar                     Sd Eibar
# 8      5358                    sd-huesca                    Sd Huesca
# 9      1108             deportivo-alaves             Deportivo Alaves
# 10    16795                   fc-granada                   Fc Granada
# 11     3368                   ud-levante                   Ud Levante
# ...

# %%
espana.count()
# Out:
# club_id                    32
# name                       32
# pretty_name                32
# domestic_competition_id    32
# total_market_value         32
# squad_size                 32
# average_age                32
# foreigners_number          32
# foreigners_percentage      32
# national_team_players      32
# stadium_name               32
# stadium_seats              32
# net_transfer_record        32
# coach_name                 32
# url                        32
# dtype: int64

# %%
espana
# CHEQUEAMOS LA TABLA Y VEMOS QUE ESTA BIEN
# Out:
#     club_id                         name                  pretty_name  \
# 0       142               real-saragossa               Real Saragossa
# 1       993                   fc-cordoba                   Fc Cordoba
# 2      2448               sporting-gijon               Sporting Gijon
# 3      1084                    fc-malaga                    Fc Malaga
# 4       897          deportivo-la-coruna          Deportivo La Coruna
# 5       472                ud-las-palmas                Ud Las Palmas
# 6      1244                   cd-leganes                   Cd Leganes
# 7      1533                     sd-eibar                     Sd Eibar
# 8      5358                    sd-huesca                    Sd Huesca
# 9      1108             deportivo-alaves             Deportivo Alaves
# 10    16795                   fc-granada                   Fc Granada
# 11     3368                   ud-levante                   Ud Levante
# ...

# %%
espana.to_csv("C:\\Users\\Gabriel Castillo\\Desktop\\GITHUB GABRIEL\\EDA\\EDATheBridge\\Futbol\\data\\filtrada\\espana.csv")
# SE CREA EL NUEVO CSV Y SE GUARDA
