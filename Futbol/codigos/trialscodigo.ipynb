# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
appearances = pd.read_csv("C:\\Users\\Gabriel Castillo\\Desktop\\GITHUB GABRIEL\\EDA\\EDATheBridge\\Futbol\\data\\appearances.csv")
clubs = pd.read_csv("C:\\Users\\Gabriel Castillo\\Desktop\\GITHUB GABRIEL\\EDA\\EDATheBridge\\Futbol\\data\\clubs.csv")
competitions = pd.read_csv("C:\\Users\\Gabriel Castillo\\Desktop\\GITHUB GABRIEL\\EDA\\EDATheBridge\\Futbol\\data\\competitions.csv")
games = pd.read_csv("C:\\Users\\Gabriel Castillo\\Desktop\\GITHUB GABRIEL\\EDA\\EDATheBridge\\Futbol\\data\\games.csv")
player_valuations = pd.read_csv("C:\\Users\\Gabriel Castillo\\Desktop\\GITHUB GABRIEL\\EDA\\EDATheBridge\\Futbol\\data\\player_valuations.csv")
players =  pd.read_csv("C:\\Users\\Gabriel Castillo\\Desktop\\GITHUB GABRIEL\\EDA\\EDATheBridge\\Futbol\\data\\players.csv")

# %%
appearances
# Out:
#          player_id  game_id   appearance_id competition_id  player_club_id  \
# 0            52453  2483937   2483937_52453            RU1           28095
# 1            67064  2479929   2479929_67064            RU1           28095
# 2            67064  2483937   2483937_67064            RU1           28095
# 3            67064  2484582   2484582_67064            RU1           28095
# 4            67064  2485965   2485965_67064            RU1           28095
# ...            ...      ...             ...            ...             ...
# 1072827     369552  3837232  3837232_369552            NL1             200
# 1072828     369552  3837391  3837391_369552            NL1             200
# 1072829     369552  3837395  3837395_369552            NL1             200
# 1072830     369552  3839703  3839703_369552            NL1             200
# 1072831     369552  3839707  3839707_369552            NL1             200
#
# ...

# %%
appearances.shape
# Out:
# (1072832, 12)

# %%
appearances.columns
# Out:
# Index(['player_id', 'game_id', 'appearance_id', 'competition_id',
#        'player_club_id', 'goals', 'assists', 'minutes_played', 'yellow_cards',
#        'red_cards', 'date', 'player_pretty_name'],
#       dtype='object')

# %%
clubs.columns
# Out:
# Index(['club_id', 'name', 'pretty_name', 'domestic_competition_id',
#        'total_market_value', 'squad_size', 'average_age', 'foreigners_number',
#        'foreigners_percentage', 'national_team_players', 'stadium_name',
#        'stadium_seats', 'net_transfer_record', 'coach_name', 'url'],
#       dtype='object')

# %%
games
# Out:
#        game_id competition_code  season                     round        date  \
# 0      2244388              SUC    2012             final 1st leg  2012-08-22
# 1      2219794             BESC    2011                     Final  2012-07-22
# 2      2244389              SUC    2012             final 2nd leg  2012-08-29
# 3      2271112              DFB    2012               Round of 16  2012-12-18
# 4      2229332              DFL    2012                     Final  2012-08-12
# ...        ...              ...     ...                       ...         ...
# 57765  3911792               CL    2022                   Group C  2022-09-13
# 57766  3901635             ECLQ    2022  Qualifying Round 2nd leg  2022-08-25
# 57767  3911795               CL    2022                   Group D  2022-09-07
# 57768  3911799               CL    2022                   Group D  2022-09-07
# 57769  3911739               CL    2022                   Group B  2022-09-13
#
# ...

# %%
games.shape
# Out:
# (57770, 18)

# %%
games.columns
# Out:
# Index(['game_id', 'competition_code', 'season', 'round', 'date',
#        'home_club_id', 'away_club_id', 'home_club_goals', 'away_club_goals',
#        'home_club_position', 'away_club_position', 'stadium', 'attendance',
#        'referee', 'url', 'club_home_pretty_name', 'club_away_pretty_name',
#        'aggregate'],
#       dtype='object')

# %%
appearances
# Out:
#          player_id  game_id   appearance_id competition_id  player_club_id  \
# 0            52453  2483937   2483937_52453            RU1           28095
# 1            67064  2479929   2479929_67064            RU1           28095
# 2            67064  2483937   2483937_67064            RU1           28095
# 3            67064  2484582   2484582_67064            RU1           28095
# 4            67064  2485965   2485965_67064            RU1           28095
# ...            ...      ...             ...            ...             ...
# 1072827     369552  3837232  3837232_369552            NL1             200
# 1072828     369552  3837391  3837391_369552            NL1             200
# 1072829     369552  3837395  3837395_369552            NL1             200
# 1072830     369552  3839703  3839703_369552            NL1             200
# 1072831     369552  3839707  3839707_369552            NL1             200
#
# ...

# %%
appearances[appearances["competition_id"]== "ES1"] 
# ¿Se puede añadir una mascara a una mascara ya hecha?
# Out:
#          player_id  game_id   appearance_id competition_id  player_club_id  \
# 2494         74314  2475355   2475355_74314            ES1             993
# 2514         74314  2475365   2475365_74314            ES1             993
# 2515         74314  2475379   2475379_74314            ES1             993
# 2516         74314  2475383   2475383_74314            ES1             993
# 2517         74314  2475392   2475392_74314            ES1             993
# ...            ...      ...             ...            ...             ...
# 1071073     229804  3885856  3885856_229804            ES1             681
# 1071074     229804  3858325  3858325_229804            ES1             681
# 1072662     372246  3844097  3844097_372246            ES1            1049
# 1072663     372246  3844593  3844593_372246            ES1            1049
# 1072664     372246  3885851  3885851_372246            ES1            1049
#
# ...

# %%
appearances[appearances["player_id"]==26].head(25)
# Out:
#         player_id  game_id appearance_id competition_id  player_club_id  \
# 129731         26  2460639    2460639_26             L1              16
# 129739         26  2460645    2460645_26             L1              16
# 129740         26  2460655    2460655_26             L1              16
# 129741         26  2460663    2460663_26             L1              16
# 129742         26  2460671    2460671_26             L1              16
# 129743         26  2460681    2460681_26             L1              16
# 129744         26  2460696    2460696_26             L1              16
# 129745         26  2460698    2460698_26             L1              16
# 129746         26  2460707    2460707_26             L1              16
# 129756         26  2460716    2460716_26             L1              16
# 129757         26  2460733    2460733_26             L1              16
# 129758         26  2460741    2460741_26             L1              16
# ...

# %%
players[players["pretty_name"].str.contains("Neymar")]
# Out:
#        player_id  last_season  current_club_id    name pretty_name  \
# 25607      68290         2022              583  neymar      Neymar
#
#       country_of_birth country_of_citizenship date_of_birth position  \
# 25607           Brazil                 Brazil    1992-02-05   Attack
#
#       sub_position  ... height_in_cm  market_value_in_gbp  \
# 25607  Left Winger  ...          175           67500000.0
#
#        highest_market_value_in_gbp  agent_name  \
# 25607                  162000000.0         NaN
#
#                                                image_url  \
# 25607  https://img.a.transfermarkt.technology/portrai...
#
#                                                      url club_id  \
# 25607  https://www.transfermarkt.co.uk/neymar/profil/...     583
#
#        domestic_competition_id               club_name        club_pretty_name
# 25607                      FR1  fc-paris-saint-germain  Fc Paris Saint Germain
#
# [1 rows x 21 columns]

# %%
players[players["domestic_competition_id"]== "ES1"].head(20)
# Out:
#       player_id  last_season  current_club_id              name  \
# 4         30802         2013             3302        oscar-diaz
# 6        117549         2013             3302        rodri-rios
# 7        186796         2013             3302    hicham-khaloua
# 135       29193         2013             3302      ruben-suarez
# 136      173559         2013             3302     cristobal-gil
# 138       35546         2013             3302            rafita
# 139       76743         2013             3302     marcelo-silva
# 140       72883         2013             3302     hans-martinez
# 141       48294         2013             3302            bolano
# 142       26801         2013             3302  hernan-pellerano
# 144      271446         2013             3302             kiutm
# 145        3755         2013             3302      oscar-ustari
# 148       74561         2013             3302     victor-ibanez
# 151       44072         2013             3302      marcos-tebar
# ...

# %%
players.shape
# Out:
# (25608, 21)

# %%
player_valuations
# Out:
#         player_id        date  market_value    datetime    dateweek  \
# 0          254016  2013-07-22         90000  2013-07-22  2013-07-22
# 1          254016  2014-01-14         90000  2014-01-14  2014-01-13
# 2           51053  2008-08-25         90000  2008-08-25  2008-08-25
# 3           51053  2011-05-30         90000  2011-05-30  2011-05-30
# 4           51053  2011-08-26        225000  2011-08-26  2011-08-22
# ...           ...         ...           ...         ...         ...
# 368805      68290  2020-10-15     115200000  2020-10-15  2020-10-12
# 368806      68290  2021-04-09      99000000  2021-04-09  2021-04-05
# 368807      68290  2021-06-04      90000000  2021-06-04  2021-05-31
# 368808      68290  2021-12-16      81000000  2021-12-16  2021-12-13
# 368809      68290  2022-05-30      67500000  2022-05-30  2022-05-30
#
#         current_club_id player_club_domestic_competition_id
# 0                   855                                 FR1
# ...

# %%
player_valuations.groupby("player_id")

# %%
player_valuations.shape
# Out:
# (368810, 7)

# %%
competitions
# Out:
#    competition_id                                         name  \
# 0              L1                                   bundesliga
# 1             DFB                                    dfb-pokal
# 2             DFL                                 dfl-supercup
# 3             NL1                                   eredivisie
# 4             NLP                              toto-knvb-beker
# 5            NLSC                         johan-cruijff-schaal
# 6             BE1                           jupiler-pro-league
# 7            BESC                             belgian-supercup
# 8             ES1                                       laliga
# 9             CDR                                 copa-del-rey
# 10            SUC                                    supercopa
# 11            PO1                           liga-portugal-bwin
# 12           POCP                                  allianz-cup
# 13           POSU                supertaca-candido-de-oliveira
# ...

# %%
competitions.shape
# Out:
# (42, 10)

# %%
competitions.loc[8]
# Out:
# competition_id                                                        ES1
# name                                                               laliga
# type                                                           first_tier
# country_id                                                            157
# country_name                                                        Spain
# domestic_league_code                                                  ES1
# confederation                                                      europa
# url                     https://www.transfermarkt.co.uk/laliga/startse...
# country_latitude                                                39.326068
# country_longitude                                               -4.837979
# Name: 8, dtype: object

# %%
clubs.head(10)
# Out:
#    club_id                    name             pretty_name  \
# 0     1032              fc-reading              Fc Reading
# 1     2323                orduspor                Orduspor
# 2     1387          acn-siena-1904          Acn Siena 1904
# 3     1071          wigan-athletic          Wigan Athletic
# 4     2703     spartak-vladikavkaz     Spartak Vladikavkaz
# 5      142          real-saragossa          Real Saragossa
# 6      566            beerschot-ac            Beerschot Ac
# 7     1436            sc-beira-mar            Sc Beira Mar
# 8     4750            sc-olhanense            Sc Olhanense
# 9       23  eintracht-braunschweig  Eintracht Braunschweig
#
#   domestic_competition_id  total_market_value  squad_size  average_age  \
# 0                     GB1               33.66          26         25.9
# 1                     TR1                 NaN           0          NaN
# 2                     IT1                4.32          30         26.2
# ...

# %%
clubs.shape
# Out:
# (410, 15)

# %%
clubs.groupby("domestic_competition_id").sum()
# Out:
#                          club_id  total_market_value  squad_size  average_age  \
# domestic_competition_id
# BE1                       129752              788.75         586        513.5
# DK1                        94061              270.47         479        433.6
# ES1                        66428             4906.26         810        862.5
# FR1                        51863             4083.51         924        855.4
# GB1                        27860             9723.19         928        919.4
# GR1                       174312              405.90         668        617.7
# IT1                        65285             4874.85        1047        919.5
# L1                         30471             3907.64         780        705.9
# NL1                        17860              995.47         733        643.2
# PO1                        89757             1314.13         815        754.8
# RU1                       317932              773.93         651        649.7
# ...

# %%
clubs["domestic_competition_id"]=="ES1"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 405    False
# 406    False
# 407    False
# 408    False
# 409    False
# Name: domestic_competition_id, Length: 410, dtype: bool

# %%
clubs.loc[clubs["domestic_competition_id"]=="ES1"]
# Out:
#      club_id                         name                  pretty_name  \
# 5        142               real-saragossa               Real Saragossa
# 26       993                   fc-cordoba                   Fc Cordoba
# 61      2448               sporting-gijon               Sporting Gijon
# 66      1084                    fc-malaga                    Fc Malaga
# 75       897          deportivo-la-coruna          Deportivo La Coruna
# 76       472                ud-las-palmas                Ud Las Palmas
# 106     1244                   cd-leganes                   Cd Leganes
# 127     1533                     sd-eibar                     Sd Eibar
# 128     5358                    sd-huesca                    Sd Huesca
# 153     1108             deportivo-alaves             Deportivo Alaves
# 154    16795                   fc-granada                   Fc Granada
# 159     3368                   ud-levante                   Ud Levante
# ...

# %%
clubs.loc[clubs["domestic_competition_id"]=="ES1"].shape
# Out:
# (32, 15)

# %%
# players.groupby("player_pretty_name").sum()

# %%
# players.shape

# %%
# players.sort_values(by = ["player_pretty_name"], ascending=[True]).sum()

# %%
# players_goals = players.groupby(by=["competition_id", "player_club_id"]).count()["player_id"]
# players_goals

# %%
# games = pd.read_csv()

# %%
a = appearances.groupby("player_pretty_name")[["goals", "assists"]].sum().sort_values(by= "goals", ascending=False)
a
# Out:
#                           goals  assists
# player_pretty_name
# Robert Lewandowski          355       72
# Lionel Messi                335      180
# Cristiano Ronaldo           324       82
# Luis Suarez                 246      114
# Harry Kane                  231       55
# ...                         ...      ...
# Lamine Diarra                 0        0
# Lamine Ndao                   0        0
# Landry Bonnefoi               0        0
# Apostolos Apostolopoulos      0        0
#  Alpha Bdul Razak             0        0
#
# [18185 rows x 2 columns]
